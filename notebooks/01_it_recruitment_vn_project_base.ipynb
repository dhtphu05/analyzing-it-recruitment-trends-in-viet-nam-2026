# %% [markdown]
# # Phan tich va du bao xu huong tuyen dung IT tai Viet Nam
#
# Notebook base cho du an crawl, lam sach, EDA va du bao muc luong.

# %% [markdown]
# ## 1. Data Loading
# - Doc du lieu tu `data/processed/jobs_features.csv`
# - Kiem tra schema va so luong gia tri thieu

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')
df = pd.read_csv('../data/processed/jobs_features.csv')
df.head()

# %% [markdown]
# ## 2. Data Cleaning Review
# - So sanh phan bo salary truoc va sau cleaning
# - Kiem tra trung lap, null, salary outlier

# %%
df.info()
df.describe(include='all').T.head(20)

# %% [markdown]
# ## 3. EDA
# - Top ky nang pho bien
# - Salary theo level
# - Salary theo location
# - Correlation heatmap

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['salary_avg'].dropna(), bins=30, kde=True)
plt.title('Salary Distribution')
plt.show()

# %% [markdown]
# ## 4. Modeling
# - Tao baseline regression model
# - Danh gia bang MAE, RMSE, R2

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 5. Conclusion
# - Tong hop insight thi truong
# - Danh gia tinh kha thi cua bai toan du bao salary
